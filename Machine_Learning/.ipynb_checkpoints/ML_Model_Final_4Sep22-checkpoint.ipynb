# %%
# Import dependencies
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import tensorflow as tf
import psycopg2
import pycaret
from pycaret.classification import *

# %% [markdown]
# ## Load Data

# %%
# Connect to postgres SQL database
conn = psycopg2.connect(database = 'postgres',
                        user =     'postgres',
                        password = 'Arya7328*',
                        host =     'bootcampproject.cs8v5ggqsbn0.us-west-1.rds.amazonaws.com',
                        port =     '5432')

# Create cursor object
cur = conn.cursor()

# Select all data from machine learning table
cur.execute('''
            SELECT *
            FROM ml_table;
            ''')

data = cur.fetchall()

# Create a dataframe
cols = []
for elt in cur.description:
    cols.append(elt[0])
        
health_df = pd.DataFrame (data=data,columns=cols)
pd.set_option('display.max_columns', None)
health_df.head(10)
# Out:
#    GENHLTH  MENTHLTH  PHYSHLTH  SEX  MARITAL_STATUS  EDUCATION  HOME_STATUS  \
# 0        3        88        88    2               2          6            1
# 1        2        88        88    2               3          3            1
# 2        2         3        88    2               3          5            1
# 3        2        88         2    1               1          6            1
# 4        3        88        88    2               3          4            1
# 5        3        88        14    2               3          3            1
# 6        3        88        88    1               1          6            1
# 7        5        99        99    1               2          4            2
# 8        4        30        28    2               1          6            1
# 9        2         5        88    2               1          6            1
#
#    VETERAN  EMPLOYMENT_SITUATION  INTERNET  DISABILITIES?  USEEQUIP  BLIND  \
# 0        2                     3         1              1         2      1
# 1        2                     2         2              1         2      2
# 2        2                     7         2              2         2      2
# 3        2                     7         1              2         2      2
# 4        2                     5         1              1         2      2
# 5        2                     7         2              1         1      2
# 6        1                     7         1              2         2      2
# 7        1                    99         2              1         1      2
# 8        2                     8         1              1         2      2
# 9        2                     1         1              2         2      2
#
#    ISSUES_DECISION_MAING  DIFFWALK  DIFFDRES  DIFFALON  HEALTHY_ADULTS  \
# 0                      1         2         2         2               1
# 1                      2         2         2         2               1
# 2                      2         2         2         2               1
# 3                      2         2         2         2               1
# 4                      2         1         2         2               1
# 5                      2         2         2         2               1
# 6                      2         2         2         2               1
# 7                      2         1         1         1               2
# 8                      1         2         2         1               2
# 9                      2         2         2         2               1
#
#    HEALTH_CVRAGE  DIABETE3  BLOOD_PRESSURE  _CHOLCHK  HIGH_CHOLESTEROL  \
# 0              2         3               1         2                 1
# 1             99         3               2         1                 1
# 2             99         3               2         1                 2
# 3             99         3               2         1                 2
# 4             99         3               2         1                 2
# 5             99         3               2         1                 2
# 6             99         1               1         1                 1
# 7              1         1               2         1                 2
# 8              1         3               1         1                 2
# 9              1         3               2         1                 1
#
#    CORONARY_DISEASE  ASTHMA_DISEASE  _ASTHMS1  HAS_ARTHRITIS  RACE  \
# 0                 2               1         3              2     1
# 1                 2               1         3              1     1
# 2                 2               1         3              2     1
# 3                 2               1         3              2     1
# 4                 2               2         1              1     1
# 5                 1               1         3              1     1
# 6                 2               1         3              1     1
# 7                 1               1         3              1     1
# 8                 2               1         3              1     1
# 9                 2               1         3              2     1
#
#    AGE_14LEVEL   BMI  4_BMI  CHILDREN2  EDUCATION_LEVEL  INCOME2  DRINKS_WEEK  \
# 0            7  2509      3          1                4        1          0.0
# 1           11  2652      3          1                1        4          0.0
# 2           11  2389      2          1                3        2         70.0
# 3           10  2522      3          1                4        5          0.0
# 4           11  2500      3          1                2        2         93.0
# 5           13  2579      3          1                1       99          0.0
# 6           13  2468      2          1                4        5         23.0
# 7           99  2848      3          1                2        2          0.0
# 8            4  3328      4          1                4        1          0.0
# 9            6  3328      4          1                4        5         93.0
#
#    HEAVY_DRINKER  FRUIT_CONSUMPTION  VEGGIE_COSUMPTION  PHYS_ACTIVITY_MINS  \
# 0              1                  2                  2               168.0
# 1              1                  1                  1               330.0
# 2              1                  1                  1               345.0
# 3              1                  1                  1               300.0
# 4              1                  2                  1               210.0
# 5              1                  1                  1                90.0
# 6              1                  1                  1               280.0
# 7              1                  1                  1                60.0
# 8              1                  2                  1                 0.0
# 9              1                  2                  2               180.0
#
#    PHYS_CATEGORIES  PHYS_ACT_INDX  AER_STRGTH
# 0                2              1           2
# 1                1              1           2
# 2                1              1           2
# 3                2              1           2
# 4                2              1           2
# 5                3              2           4
# 6                2              1           2
# 7                3              2           4
# 8               99             99          99
# 9                2              1           1

# %% [markdown]
# ## Check Preprocessing

# %%
# Check size and shape of dataframe
health_df.shape
# Out:
# (222168, 42)

# %%
# Check data types
health_df.dtypes
# Out:
# GENHLTH                    int64
# MENTHLTH                   int64
# PHYSHLTH                   int64
# SEX                        int64
# MARITAL_STATUS             int64
# EDUCATION                  int64
# HOME_STATUS                int64
# VETERAN                    int64
# EMPLOYMENT_SITUATION       int64
# INTERNET                   int64
# DISABILITIES?              int64
# USEEQUIP                   int64
# BLIND                      int64
# ISSUES_DECISION_MAING      int64
# DIFFWALK                   int64
# DIFFDRES                   int64
# DIFFALON                   int64
# HEALTHY_ADULTS             int64
# HEALTH_CVRAGE              int64
# DIABETE3                   int64
# BLOOD_PRESSURE             int64
# _CHOLCHK                   int64
# HIGH_CHOLESTEROL           int64
# CORONARY_DISEASE           int64
# ASTHMA_DISEASE             int64
# _ASTHMS1                   int64
# HAS_ARTHRITIS              int64
# RACE                       int64
# AGE_14LEVEL                int64
# BMI                        int64
# 4_BMI                      int64
# CHILDREN2                  int64
# EDUCATION_LEVEL            int64
# INCOME2                    int64
# DRINKS_WEEK              float64
# HEAVY_DRINKER              int64
# FRUIT_CONSUMPTION          int64
# VEGGIE_COSUMPTION          int64
# PHYS_ACTIVITY_MINS       float64
# PHYS_CATEGORIES            int64
# PHYS_ACT_INDX              int64
# AER_STRGTH                 int64
# dtype: object

# %%
# Double check for null values
health_df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### For numerical, ordered data, change none code (88) to 0, change did not respond code (99) to median of the feature, and removed outliers in skewed distributions

# %%
# GENHLTH: values over 5 changed to median
for index, row in health_df.iterrows():
    if health_df.loc[index, 'GENHLTH'] > 5:
        health_df.loc[index, 'GENHLTH'] = health_df.GENHLTH.median()

# %%
# MENTHLTH: 88 changed to 0, 99 and over 30 changed to median
for index, row in health_df.iterrows():
    if health_df.loc[index, 'MENTHLTH'] == 88:
        health_df.loc[index, 'MENTHLTH'] = 0
    elif (health_df.loc[index, 'MENTHLTH'] == 99) or (health_df.loc[index,'MENTHLTH'] > 30):
        health_df.loc[index, 'MENTHLTH'] = health_df.MENTHLTH.median()

# %%
# PHYSHLTH: 88 changed to 0, 99 and over 30 changed to median
for index, row in health_df.iterrows():
    if health_df.loc[index, 'PHYSHLTH'] == 88:
        health_df.loc[index, 'PHYSHLTH'] = 0
    elif (health_df.loc[index, 'PHYSHLTH'] == 99) or (health_df.loc[index,'PHYSHLTH'] > 30):
        health_df.loc[index, 'PHYSHLTH'] = health_df.PHYSHLTH.median()

# %%
# AGE_14LEVEL: values over 13 changed to median
for index, row in health_df.iterrows():
    if health_df.loc[index, 'AGE_14LEVEL'] > 13:
        health_df.loc[index, 'AGE_14LEVEL'] = health_df.AGE_14LEVEL.median()

# %%
# For the following columns, values over 8 changed to median
change_cols = ['CHILDREN2', 'EDUCATION_LEVEL', 'INCOME2', 'PHYS_CATEGORIES']
for col in change_cols:
    for index, row in health_df.iterrows():
        if health_df.loc[index, col] > 8:
            health_df.loc[index, col] = health_df[col].median()

# %%
# BMI: Remove outliers
for index, row in health_df.iterrows():
    if health_df.loc[index, 'BMI'] > 6000:
        health_df.loc[index, 'BMI'] = health_df.BMI.median()

# %%
# PHYS_ACTIVITY_MINS: Remove outliers
for index, row in health_df.iterrows():
    if health_df.loc[index, 'PHYS_ACTIVITY_MINS'] > 5000:
        health_df.loc[index, 'PHYS_ACTIVITY_MINS'] = health_df.PHYS_ACTIVITY_MINS.median()

# %%
# DRINKS_WEEK: Remove outliers
for index, row in health_df.iterrows():
    if health_df.loc[index, 'DRINKS_WEEK'] > 1500:
        health_df.loc[index, 'DRINKS_WEEK'] = health_df.DRINKS_WEEK.median()

# %%
# Look at histogram of target (MENTHLTH) to decide bin ranges
health_df.hist(column='MENTHLTH')
# Out:
# array([[<AxesSubplot:title={'center':'MENTHLTH'}>]], dtype=object)

# %%
# Create 2 bins for mental health. One at 0, one from 1-30
for index, row in health_df.iterrows():
    if health_df.loc[index,'MENTHLTH'] > 0:
        health_df.loc[index, 'MENTHLTH'] = 1

# %%
# Check target column bins
health_df.hist(column='MENTHLTH')
# Out:
# array([[<AxesSubplot:title={'center':'MENTHLTH'}>]], dtype=object)

# %%
# Save cleaned health_df to csvs
health_df.to_csv("cleaned_health_df")

# %% [markdown]
# ## Feature Selection

# %%
# PyCaret Setup
# "Normalize = True" scales the data based on z-score
# "transformation = True" changes the shape of the distribution to approximately normal
# "bin_numeric_features" creates bins for continuous categorical features based on sturges rule and K-means clusters
exp_clf101 = setup(data = health_df, target = 'MENTHLTH', session_id=123,
                   normalize = True,
                   transformation = True,
                   bin_numeric_features = ['PHYSHLTH', 'BMI', 'PHYS_ACTIVITY_MINS', 'DRINKS_WEEK'])
# Out:
# <style type="text/css">
# #T_995e7_row8_col1, #T_995e7_row13_col1, #T_995e7_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_995e7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_995e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_995e7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_995e7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_995e7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_995e7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_995e7_row1_col1" class="data row1 col1" >MENTHLTH</td>
#     </tr>
#     <tr>
#       <th id="T_995e7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_995e7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_0f544_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0f544_row10_col0" class="data row10 col0" >0.7490</td>
#       <td id="T_0f544_row10_col1" class="data row10 col1" >0.7134</td>
#       <td id="T_0f544_row10_col2" class="data row10 col2" >0.2999</td>
#       <td id="T_0f544_row10_col3" class="data row10 col3" >0.6157</td>
#       <td id="T_0f544_row10_col4" class="data row10 col4" >0.4033</td>
#       <td id="T_0f544_row10_col5" class="data row10 col5" >0.2676</td>
#       <td id="T_0f544_row10_col6" class="data row10 col6" >0.2954</td>
#     </tr>
#     <tr>
#       <th id="T_0f544_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0f544_row11_col0" class="data row11 col0" >0.0015</td>
#       <td id="T_0f544_row11_col1" class="data row11 col1" >0.0023</td>
#       <td id="T_0f544_row11_col2" class="data row11 col2" >0.0068</td>
#       <td id="T_0f544_row11_col3" class="data row11 col3" >0.0049</td>
#       <td id="T_0f544_row11_col4" class="data row11 col4" >0.0065</td>
#       <td id="T_0f544_row11_col5" class="data row11 col5" >0.0059</td>
#       <td id="T_0f544_row11_col6" class="data row11 col6" >0.005
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# Feature importance plot
plot_model(rf, plot='feature_all')

# %%
# Keep only 27 highest features (over 0.015 variable importance)
highest_features = ['MENTHLTH','AGE_14LEVEL','BMI','EMPLOYMENT_SITUATION','ISSUES_DECISION_MAING','GENHLTH','INCOME2', \
                    'DRINKS_WEEK','MARITAL_STATUS','AER_STRGTH','4_BMI','PHYSHLTH','PHYS_ACTIVITY_MINS','CHILDREN2', \
                    'EDUCATION','FRUIT_CONSUMPTION','EDUCATION_LEVEL','PHYS_CATEGORIES','HIGH_CHOLESTEROL', \
                    'BLOOD_PRESSURE','RACE','VEGGIE_COSUMPTION','HEALTH_CVRAGE','HOME_STATUS','DIABETE3','DISABILITIES?', \
                    'HAS_ARTHRITIS','SEX']

fs_health_df = health_df.filter(highest_features, axis=1)

# %% [markdown]
# ## Split Data and Setup PyCaret

# %%
# Separate data into training and testing sets
data = fs_health_df.sample(frac=0.95, random_state=123).reset_index(drop=True)
data_unseen = fs_health_df.drop(data.index).reset_index(drop=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (211060, 28)
# Unseen Data For Predictions: (11108, 28)

# %%
# PyCaret Setup
# "normalize = True" scales the data based on z-score
# "transformation = True" changes the shape of the distribution to approximately normal
# "bin_numeric_features" creates bins for continuous categorical features based on sturges rule and K-means clusters
exp_clf101 = setup(data = data, 
                   target = 'MENTHLTH',
                   session_id=123,
                   normalize = True,
                   transformation = True,
                   bin_numeric_features = ['PHYSHLTH', 'BMI', 'PHYS_ACTIVITY_MINS', 'DRINKS_WEEK'])
# Out:
# <style type="text/css">
# #T_a9737_row8_col1, #T_a9737_row13_col1, #T_a9737_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a9737_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9737_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9737_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a9737_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9737_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a9737_row1_col1" class="data row1 col1" >MENTHLTH</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9737_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a9737_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a9737_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a9737_row3_col1" class="data row3 col1" >(211060, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a9737_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a9737_row4_col1" class="data row4 col1" >(211060, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a9737_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a9737_row5_col1" class="data row5 col1" >(147741, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a9737_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a9737_row6_col1" class="data row6 col1" >(63319, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a9737_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a9737_row7_col1" class="data row7 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a9737_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_a9737_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a9737_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_a9737_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a9737_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_a9737_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a9737_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_a9737_row11_col1" class="data row11 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a9737_row12_col0" class="data row12 col0" >Low variance threshold</td>
#       <td id="T_a9737_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a9737_row13_col0" class="data row13 col0" >Transformation</td>
#       <td id="T_a9737_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a9737_row14_col0" class="data row14 col0" >Transformation method</td>
#       <td id="T_a9737_row14_col1" class="data row14 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a9737_row15_col0" class="data row15 col0" >Normalize</td>
#       <td id="T_a9737_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a9737_row16_col0" class="data row16 col0" >Normalize method</td>
#       <td id="T_a9737_row16_col1" class="data row16 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a9737_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_a9737_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a9737_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_a9737_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a9737_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_a9737_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a9737_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_a9737_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a9737_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_a9737_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a9737_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_a9737_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a9737_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a9737_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_a9737_row23_col1" class="data row23 col1" >c44d</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Compare Binary Classification Machine Learning Models

# %%
# Model training and selection (runtime ~ 35min)
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_824ad_ th {
#   text-align: left;
# }
# #T_824ad_row0_col0, #T_824ad_row0_col2, #T_824ad_row0_col3, #T_824ad_row0_col4, #T_824ad_row0_col5, #T_824ad_row0_col6, #T_824ad_row0_col7, #T_824ad_row1_col0, #T_824ad_row1_col1, #T_824ad_row1_col3, #T_824ad_row1_col4, #T_824ad_row1_col5, #T_824ad_row1_col6, #T_824ad_row2_col0, #T_824ad_row2_col1, #T_824ad_row2_col2, #T_824ad_row2_col3, #T_824ad_row2_col4, #T_824ad_row2_col5, #T_824ad_row2_col6, #T_824ad_row2_col7, #T_824ad_row3_col0, #T_824ad_row3_col1, #T_824ad_row3_col2, #T_824ad_row3_col3, #T_824ad_row3_col4, #T_824ad_row3_col5, #T_824ad_row3_col6, #T_824ad_row3_col7, #T_824ad_row4_col0, #T_824ad_row4_col1, #T_824ad_row4_col2, #T_824ad_row4_col3, #T_824ad_row4_col4, #T_824ad_row4_col5, #T_824ad_row4_col6, #T_824ad_row4_col7, #T_824ad_row5_col0, #T_824ad_row5_col1, #T_824ad_row5_col2, #T_824ad_row5_col3, #T_824ad_row5_col4, #T_824ad_row5_col5, #T_824ad_row5_col6, #T_824ad_row5_col7, #T_824ad_row6_col0, #T_824ad_row6_col1, #T_824ad_row6_col2, #T_824ad_row6_col3, #T_824ad_row6_col4, #T_824ad_row6_col5, #T_824ad_row6_col7, #T_824ad_row7_col0, #T_824ad_row7_col1, #T_824ad_row7_col2, #T_824ad_row7_col3, #T_824ad_row7_col5, #T_824ad_row7_col6, #T_824ad_row7_col7, #T_824ad_row8_col0, #T_824ad_row8_col1, #T_824ad_row8_col2, #T_824ad_row8_col3, #T_824ad_row8_col4, #T_824ad_row8_col5, #T_824ad_row8_col6, #T_824ad_row8_col7, #T_824ad_row9_col0, #T_824ad_row9_col1, #T_824ad_row9_col2, #T_824ad_row9_col3, #T_824ad_row9_col4, #T_824ad_row9_col5, #T_824ad_row9_col6, #T_824ad_row9_col7, #T_824ad_row10_col0, #T_824ad_row10_col1, #T_824ad_row10_col2, #T_824ad_row10_col3, #T_824ad_row10_col4, #T_824ad_row10_col6, #T_824ad_row10_col7, #T_824ad_row11_col0, #T_824ad_row11_col1, #T_824ad_row11_col2, #T_824ad_row11_col3, #T_824ad_row11_col4, #T_824ad_row11_col5, #T_824ad_row11_col6, #T_824ad_row11_col7, #T_824ad_row12_col0, #T_824ad_row12_col1, #T_824ad_row12_col2, #T_824ad_row12_col3, #T_824ad_row12_col4, #T_824ad_row12_col5, #T_824ad_row12_col6, #T_824ad_row12_col7, #T_824ad_row13_col0, #T_824ad_row13_col1, #T_824ad_row13_col2, #T_824ad_row13_col4, #T_824ad_row13_col5, #T_824ad_row13_col6, #T_824ad_row13_col7 {
#   text-align: left;
# }
# #T_824ad_row0_col1, #T_824ad_row1_col2, #T_824ad_row1_col7, #T_824ad_row6_col6, #T_824ad_row7_col4, #T_824ad_row10_col5, #T_824ad_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T
level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_824ad_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_824ad_row4_col1" class="data row4 col1" >0.7552</td>
#       <td id="T_824ad_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_824ad_row4_col3" class="data row4 col3" >0.2515</td>
#       <td id="T_824ad_row4_col4" class="data row4 col4" >0.6837</td>
#       <td id="T_824ad_row4_col5" class="data row4 col5" >0.3677</td>
#       <td id="T_824ad_row4_col6" class="data row4 col6" >0.2542</td>
#       <td id="T_824ad_row4_col7" class="data row4 col7" >0.3032</td>
#       <td id="T_824ad_row4_col8" class="data row4 col8" >0.1560</td>
#     </tr>
#     <tr>
#       <th id="T_824ad_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_824ad_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_824ad_row5_col1" class="data row5 col1" >0.7551</td>
#       <td id="T_824ad_row5_col2" class="data row5 col2" >0.7307</td>
#       <td id="T_824ad_row5_col3" class="data row5 col3" >0.2839</td>
#       <td id="T_824ad_row5_col4" class="data row5 col4" >0.6556</td>
#       <td id="T_824ad_row5_col5" class="data row5 col5" >0.3961</td>
#       <td id="T_824ad_row5_col6" class="data row5 col6" >0.2716</td>
#       <td id="T_824ad_row5_col7" class="data row5 col7" >0.3090</td>
#       <td id="T_824ad_row5_col8" class="data row5 col8" >0.5460</td>
#     </tr>
#     <tr>
#       <th id="T_824ad_level0_row6" class="row_heading level0 row6" >qda</th>
#       <td id="T_824ad_row6_col0" class="data row6 col0" >Quadr
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
# Best performing model (by accuracy)
print(best_model)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=123, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
# Create gradient boosting classifier model
gbc = create_model('gbc')
# Out:
# <style type="text/css">
# #T_d1f5e_row10_col0, #T_d1f5e_row10_col1, #T_d1f5e_row10_col2, #T_d1f5e_row10_col3, #T_d1f5e_row10_col4, #T_d1f5e_row10_col5, #T_d1f5e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d1f5e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1f5e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d1f5e_row0_col0" class="data row0 col0" >0.7561</td>
#       <td id="T_d1f5e_row0_col1" class="data row0 col1" >0.7406</td>
#       <td id="T_d1f5e_row0_col2" class="data row0 col2" >0.2719</td>
#       <td id="T_d1f5e_row0_col3" class="data row0 col3" >0.6704</td>
#       <td id="T_d1f5e_row0_col4" class="data row0 col4" >0.3869</td>
#       <td id="T_d1f5e_row0_col5" class="data row0 col5" >0.2672</td>
#       <td id="T_d1f5e_row0_col6" class="data row0 col6" >0.3096</td>
#     </tr>
#     <tr>
#       <th id="T_d1f5e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d1f5e_row1_col0" class="data row1 col0" >0.7585</td>
#       <td id="T_d1f5e_row1_col1" class="data row1 col1" >0.7422</td>
#       <td id="T_d1f5e_row1_col2" class="data row1 col2" >0.2617</td>
#       <td id="T_d1f5e_row1_col3" class="data row1 col3" >0.6946</td>
#       <td id="T_d1f5e_row1_col4" class="data row1 col4" >0.3801</td>
#       <td id="T_d1f5e_row1_col5" class="data row1 col5" >0.2665</td>
#       <td id="T_d1f5e_row1_col6" class="data row1 col6" >0.3156</td>
#     </tr>
#     <tr>
#       <th id="T_d1f5e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d1f5e_row2_col0" class="data row2 col0" >0.7603</td>
#       <td id="T_d1f5e_row2_col1" class="data row2 col1" >0.7387</td>
#       <td id="T_d1f5e_row2_col2" class="data row2 col2" >0.2717</td>
#       <td id="T_d1f5e_row2_col3" class="data row2 col3" >0.6961</td>
#       <td id="T_d1f5e_row2_col4" class="data row2 col4" >0.3908</td>
#       <td id="T_d1f5e_row2_col5" class="data row2 col5" >0.2758</td>
#       <td id="T_d1f5e_row2_col6" class="data row2 col6" >0.3232</td>
#     </tr>
#     <tr>
#       <th id="T_d1f5e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d1f5e_row3_col0" class="data row3 col0" >0.7569</td>
#       <td id="T_d1f5e_row3_col1" class="data row3 col1" >0.7347</td>
#       <td id="T_d1f5e_row3_col2" class="data row3 col2" >0.2669</td>
#       <td id="T_d1f5e_row3_col3" class="data row3 col3" >0.6797</td>
#       <td id="T_d1f5e_row3_col4" class="data row3 col4" >0.3833</td>
#       <td id="T_d1f5e_row3_col5" class="data row3 col5" >0.2662</td>
#       <td id="T_d1f5e_row3_col6" class="data row3 col6" >0.3114</td>
#     </tr>
#     <tr>
#       <th id="T_d1f5e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d1f5e_row4_col0" class="data row4 col0" >0.7592</td>
#       <td id="T_d1f5e_row4_col1" class="data row4 col1" >0.7413</td>
#       <td id="T_d1f5e_row4_col2" class="data row4 col2" >0.2712</td>
#       <td id="T_d1f5e_row4_col3" class="data row4 col3" >0.6894</td>
#       <td id="T_d1f5e_row4_col4" class="data row4 col4" >0.3893</td>
#       <td id="T_d1f5e_row4_col5" class="data row4 col5" >0.2731</td>
#       <td id="T_d1f5e_row4_col6" class="data row4 col6" >0.3193</td>
#     </tr>
#     <tr>
#       <th id="T_d1f5e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d1f5e_row5_col0" class="data row5 col0" >0.7603</td>
#       <td id="T_d1f5e_row5_col1" class="data row5 col1" >0.7461</td>
#       <td id="T_d1f5e_row5_col2" class="data row5 col2" >0.2704</td>
#       <td id="T_d1f5e_row5_col3" class="data row5 col3" >0.6973</td>
#       <td id="T_d1f5e_row5_col4" class="data row5 col4" >0.3897</td>
#       <td id="T_d1f5e_row5_col5" class="data row5 col5" >0.2750</td>
#       <td id="T_d1f5e_row5_col6" class="data row5 col6" >0.3229</td>
#     </tr>
#     <tr>
#       <th id="T_d1f5e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d1f5e_row6_col0" class="data row6 col0" >0.7542</td>
#       <td id="T_d1f5e_row6_col1" class="data row6 col1" >0.7410</td>
#       <td id="T_d1f5e_row6_col2" class="data row6 col2" >0.2628</td>
#       <td id="T_d1f5e_row6_col3" class="data row6 col3" >0.6669</td>
#       <td id="T_d1f5e_row6_col4" class="data row6 col4" >0.3770</td>
#       <td id="T_d1f5e_row6_col5" class="data row6 col5" >0.2583</td>
#       <td id="T_d1f5e_row6_col6" class="data row6 col6" >0.3019</td>
#     </tr>
#     <tr>
#       <th id="T_d1f5e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d1f5e_row7_col0" class="data row7 col0" >0.7595</td>
#       <td id="T_d1f5e_row7_col1" class="data row7 col1" >0.7368</td>
#       <td id="T_d1f5e_row7_col2" class="data row7 col2" >0.2707</td>
#       <td id="T_d1f5e_row7_col3" class="data row7 col3" >0.6924</td>
#       <td id="T_d1f5e_row7_col4" class="data row7 col4" >0.3892</td>
#       <td id="T_d1f5e_row7_col5" class="data row7 col5" >0.2736</td>
#       <td id="T_d1f5e_row7_col6" class="data row7 col6" >0.3205</td>
#     </tr>
#     <tr>
#       <th id="T_d1f5e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d1f5e_row8_col0" class="data row8 col0" >0.7552</td>
#       <td id="T_d1f5e_row8_col1" class="data row8 col1" >0.7351</td>
#       <td id="T_d1f5e_row8_col2" class="data row8 col2" >0.2578</td>
#       <td id="T_d1f5e_row8_col3" class="data row8 col3" >0.6780</td>
#       <td id="T_d1f5e_row8_col4" class="data row8 col4" >0.3735</td>
#       <td id="T_d1f5e_row8_col5" class="data row8 col5" >0.2578</td>
#       <td id="T_d1f5e_row8_col6" class="data row8 col6" >0.3044</td>
#     </tr>
#     <tr>
#       <th id="T_d1f5e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d1f5e_row9_col0" class="data row9 col0" >0.7563</td>
#       <td id="T_d1f5e_row9_col1" class="data row9 col1" >0.7380</td>
#       <td id="T_d1f5e_row9_col2" class="data row9 col2" >0.2594</td>
#       <td id="T_d1f5e_row9_col3" class="data row9 col3" >0.6828</td>
#       <td id="T_d1f5e_row9_col4" class="data row9 col4" >0.3760</td>
#       <td id="T_d1f5e_row9_col5" class="data row9 col5" >0.2608</td>
#       <td id="T_d1f5e_row9_col6" class="data row9 col6" >0.3081</td>
#     </tr>
#     <tr>
#       <th id="T_d1f5e_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d1f5e_row10_col0" class="data row10 col0" >0.7576</td>
#       <td id="T_d1f5e_row10_col1" class="data row10 col1" >0.7395</td>
#       <td id="T_d1f5e_row10_col2" class="data row10 col2" >0.2665</td>
#       <td id="T_d1f5e_row10_col3" class="data row10 col3" >0.6847</td>
#       <td id="T_d1f5e_row10_col4" class="data row10 col4" >0.3836</td>
#       <td id="T_d1f5e_row10_col5" class="data row10 col5" >0.2674</td>
#       <td id="T_d1f5e_row10_col6" class="data row10 col6" >0.3137</td>
#     </tr>
#     <tr>
#       <th id="T_d1f5e_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d1f5e_row11_col0" class="data row11 col0" >0.0021</td>
#       <td id="T_d1f5e_row11_col1" class="data row11 col1" >0.0033</td>
#       <td id="T_d1f5e_row11_col2" class="data row11 col2" >0.0052</td>
#       <td id="T_d1f5e_row11_col3" class="data row11 col3" >0.0103</td>
#       <td id="T_d1f5e_row11_col4" class="data row11 col4" >0.0062</td>
#       <td id="T_d1f5e_row11_col5" class="data row11 col5" >0.0065</td>
#       <td id="T_d1f5e_row11_col6" class="data row11 col6" >0.007
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ## Tune Model and Analyze Performance

# %%
# Automatically tune model parameters using PyCaret (runtime ~ 25min)
tuned_gbc = tune_model(gbc)
# Out:
# <style type="text/css">
# #T_478f7_row10_col0, #T_478f7_row10_col1, #T_478f7_row10_col2, #T_478f7_row10_col3, #T_478f7_row10_col4, #T_478f7_row10_col5, #T_478f7_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_478f7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_478f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_478f7_row0_col0" class="data row0 col0" >0.7529</td>
#       <td id="T_478f7_row0_col1" class="data row0 col1" >0.7338</td>
#       <td id="T_478f7_row0_col2" class="data row0 col2" >0.3082</td>
#       <td id="T_478f7_row0_col3" class="data row0 col3" >0.6297</td>
#       <td id="T_478f7_row0_col4" class="data row0 col4" >0.4139</td>
#       <td id="T_478f7_row0_col5" class="data row0 col5" >0.2799</td>
#       <td id="T_478f7_row0_col6" class="data row0 col6" >0.3086</td>
#     </tr>
#     <tr>
#       <th id="T_478f7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_478f7_row1_col0" class="data row1 col0" >0.7563</td>
#       <td id="T_478f7_row1_col1" class="data row1 col1" >0.7380</td>
#       <td id="T_478f7_row1_col2" class="data row1 col2" >0.2980</td>
#       <td id="T_478f7_row1_col3" class="data row1 col3" >0.6517</td>
#       <td id="T_478f7_row1_col4" class="data row1 col4" >0.4090</td>
#       <td id="T_478f7_row1_col5" class="data row1 col5" >0.2814</td>
#       <td id="T_478f7_row1_col6" class="data row1 col6" >0.3156</td>
#     </tr>
#     <tr>
#       <th id="T_478f7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_478f7_row2_col0" class="data row2 col0" >0.7531</td>
#       <td id="T_478f7_row2_col1" class="data row2 col1" >0.7294</td>
#       <td id="T_478f7_row2_col2" class="data row2 col2" >0.2985</td>
#       <td id="T_478f7_row2_col3" class="data row2 col3" >0.6361</td>
#       <td id="T_478f7_row2_col4" class="data row2 col4" >0.4063</td>
#       <td id="T_478f7_row2_col5" class="data row2 col5" >0.2753</td>
#       <td id="T_478f7_row2_col6" class="data row2 col6" >0.3067</td>
#     </tr>
#     <tr>
#       <th id="T_478f7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_478f7_row3_col0" class="data row3 col0" >0.7564</td>
#       <td id="T_478f7_row3_col1" class="data row3 col1" >0.7288</td>
#       <td id="T_478f7_row3_col2" class="data row3 col2" >0.3093</td>
#       <td id="T_478f7_row3_col3" class="data row3 col3" >0.6452</td>
#       <td id="T_478f7_row3_col4" class="data row3 col4" >0.4181</td>
#       <td id="T_478f7_row3_col5" class="data row3 col5" >0.2874</td>
#       <td id="T_478f7_row3_col6" class="data row3 col6" >0.3185</td>
#     </tr>
#     <tr>
#       <th id="T_478f7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_478f7_row4_col0" class="data row4 col0" >0.7539</td>
#       <td id="T_478f7_row4_col1" class="data row4 col1" >0.7329</td>
#       <td id="T_478f7_row4_col2" class="data row4 col2" >0.3028</td>
#       <td id="T_478f7_row4_col3" class="data row4 col3" >0.6371</td>
#       <td id="T_478f7_row4_col4" class="data row4 col4" >0.4105</td>
#       <td id="T_478f7_row4_col5" class="data row4 col5" >0.2791</td>
#       <td id="T_478f7_row4_col6" class="data row4 col6" >0.3099</td>
#     </tr>
#     <tr>
#       <th id="T_478f7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_478f7_row5_col0" class="data row5 col0" >0.7523</td>
#       <td id="T_478f7_row5_col1" class="data row5 col1" >0.7390</td>
#       <td id="T_478f7_row5_col2" class="data row5 col2" >0.3066</td>
#       <td id="T_478f7_row5_col3" class="data row5 col3" >0.6281</td>
#       <td id="T_478f7_row5_col4" class="data row5 col4" >0.4120</td>
#       <td id="T_478f7_row5_col5" class="data row5 col5" >0.2780</td>
#       <td id="T_478f7_row5_col6" class="data row5 col6" >0.3067</td>
#     </tr>
#     <tr>
#       <th id="T_478f7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_478f7_row6_col0" class="data row6 col0" >0.7497</td>
#       <td id="T_478f7_row6_col1" class="data row6 col1" >0.7314</td>
#       <td id="T_478f7_row6_col2" class="data row6 col2" >0.2920</td>
#       <td id="T_478f7_row6_col3" class="data row6 col3" >0.6236</td>
#       <td id="T_478f7_row6_col4" class="data row6 col4" >0.3977</td>
#       <td id="T_478f7_row6_col5" class="data row6 col5" >0.2650</td>
#       <td id="T_478f7_row6_col6" class="data row6 col6" >0.2955</td>
#     </tr>
#     <tr>
#       <th id="T_478f7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_478f7_row7_col0" class="data row7 col0" >0.7525</td>
#       <td id="T_478f7_row7_col1" class="data row7 col1" >0.7280</td>
#       <td id="T_478f7_row7_col2" class="data row7 col2" >0.3056</td>
#       <td id="T_478f7_row7_col3" class="data row7 col3" >0.6296</td>
#       <td id="T_478f7_row7_col4" class="data row7 col4" >0.4115</td>
#       <td id="T_478f7_row7_col5" class="data row7 col5" >0.2779</td>
#       <td id="T_478f7_row7_col6" class="data row7 col6" >0.3070</td>
#     </tr>
#     <tr>
#       <th id="T_478f7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_478f7_row8_col0" class="data row8 col0" >0.7494</td>
#       <td id="T_478f7_row8_col1" class="data row8 col1" >0.7270</td>
#       <td id="T_478f7_row8_col2" class="data row8 col2" >0.2924</td>
#       <td id="T_478f7_row8_col3" class="data row8 col3" >0.6218</td>
#       <td id="T_478f7_row8_col4" class="data row8 col4" >0.3978</td>
#       <td id="T_478f7_row8_col5" class="data row8 col5" >0.2646</td>
#       <td id="T_478f7_row8_col6" class="data row8 col6" >0.2946</td>
#     </tr>
#     <tr>
#       <th id="T_478f7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_478f7_row9_col0" class="data row9 col0" >0.7515</td>
#       <td id="T_478f7_row9_col1" class="data row9 col1" >0.7293</td>
#       <td id="T_478f7_row9_col2" class="data row9 col2" >0.2936</td>
#       <td id="T_478f7_row9_col3" class="data row9 col3" >0.6310</td>
#       <td id="T_478f7_row9_col4" class="data row9 col4" >0.4008</td>
#       <td id="T_478f7_row9_col5" class="data row9 col5" >0.2694</td>
#       <td id="T_478f7_row9_col6" class="data row9 col6" >0.3009</td>
#     </tr>
#     <tr>
#       <th id="T_478f7_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_478f7_row10_col0" class="data row10 col0" >0.7528</td>
#       <td id="T_478f7_row10_col1" class="data row10 col1" >0.7318</td>
#       <td id="T_478f7_row10_col2" class="data row10 col2" >0.3007</td>
#       <td id="T_478f7_row10_col3" class="data row10 col3" >0.6334</td>
#       <td id="T_478f7_row10_col4" class="data row10 col4" >0.4078</td>
#       <td id="T_478f7_row10_col5" class="data row10 col5" >0.2758</td>
#       <td id="T_478f7_row10_col6" class="data row10 col6" >0.3064</td>
#     </tr>
#     <tr>
#       <th id="T_478f7_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_478f7_row11_col0" class="data row11 col0" >0.0022</td>
#       <td id="T_478f7_row11_col1" class="data row11 col1" >0.0039</td>
#       <td id="T_478f7_row11_col2" class="data row11 col2" >0.0063</td>
#       <td id="T_478f7_row11_col3" class="data row11 col3" >0.0089</td>
#       <td id="T_478f7_row11_col4" class="data row11 col4" >0.0066</td>
#       <td id="T_478f7_row11_col5" class="data row11 col5" >0.0070</td>
#       <td id="T_478f7_row11_col6" class="data row11 col6" >0.007
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# Precision Recall Curve
plot_model(tuned_gbc, plot = 'pr')

# %%
# Confusion Matrix
plot_model(tuned_gbc, plot = 'confusion_matrix')

# %%
# Predict using held-back test sample
predict_model(tuned_gbc);
# Out:
# <style type="text/css">
# </style>
# <table id="T_a18f1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a18f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a18f1_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_a18f1_row0_col1" class="data row0 col1" >0.7587</td>
#       <td id="T_a18f1_row0_col2" class="data row0 col2" >0.7382</td>
#       <td id="T_a18f1_row0_col3" class="data row0 col3" >0.2678</td>
#       <td id="T_a18f1_row0_col4" class="data row0 col4" >0.6897</td>
#       <td id="T_a18f1_row0_col5" class="data row0 col5" >0.3858</td>
#       <td id="T_a18f1_row0_col6" class="data row0 col6" >0.2703</td>
#       <td id="T_a18f1_row0_col7" class="data row0 col7" >0.3172</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save the model
save_model(tuned_gbc,'Final_GBC_Model_4Sep22')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=C:\Users\kylie\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['AGE_14LEVEL', 'BMI',
#                                               'EMPLOYMENT_SITUATION',
#                                               'ISSUES_DECISION_MAING', 'GENHLTH',
#                                               'INCOME2', 'DRINKS_WEEK',
#                                               'MARITAL_STATUS', 'AER_STRGTH',
#                                               '4_BMI', 'PHYSHLTH',
#                                               'PHYS_ACTIVITY_MINS', 'CHILDREN2',
#                                               'EDUCATION', 'FRUIT_CONSU...
#                                              criterion='friedman_mse', init=None,
#                                              learning_rate=0.1, loss='deviance',
#                                              max_depth=3, max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100,
#                                              n_iter_no_change=None,
#                                              random_state=123, subsample=1.0,
#                                              tol=0.0001, validation_fraction=0.1,
#                                              verbose=0, warm_start=False)]],
#           verbose=False),
#  'Final_GBC_Model_4Sep22.pkl')
